# %%
import sys; sys.path.append('../3rdparty/ElasticRods/python')
import elastic_rods, elastic_knots
import numpy as np, matplotlib.pyplot as plt, time, io, os
from scipy.sparse import coo_matrix
from scipy.sparse.linalg import eigsh
from scipy.linalg import eigh

from helpers import *
from parametric_curves import *
import py_newton_optimizer 

from linkage_vis import LinkageViewer as Viewer, CenterlineViewer
from tri_mesh_viewer import PointCloudViewer, PointCloudMesh

# %load_ext autoreload
# %autoreload 2

import parallelism
parallelism.set_max_num_tbb_threads(1)

from MEP import MEP

# %%
start_file = "../data/NoCollision/reduced0033.obj"
#start_file = "../data/4_1-smooth.obj"
goal_file = "../data/NoCollision/reduced0001.obj"
mep = MEP(start_file,goal_file,size_reduction=4,contact_stiffness=10000, hasCollisions=False)
cp = mep.getContactProblem()
print(cp.hasCollisions())
# Out:
# False

# %%
path = mep.loadPath('Paths/optimizedoptimizedoptimizedshortendASaddleBpath.npz')

# %%
view = Viewer(mep.getRodList(), width=1024, height=800)
mep.setViewer(view)
view.show()
# Out:
# Renderer(camera=PerspectiveCamera(aspect=1.28, children=(PointLight(color='#999999', position=(0.0, 0.0, 5.0),…

# %%
def gradient(cp):
    g = cp.gradient()
    return np.array(g)

def hessian(cp):
    #kernel dies trying to get the hessian
    H = cp.hessian()
    
    
    
    triplets = list(H.entries())
    rows = np.array([t.i for t in triplets])
    cols = np.array([t.j for t in triplets])
    vals = np.array([t.v for t in triplets])

    n_rows = int(rows.max()) + 1
    n_cols = int(cols.max()) + 1
    H_np = np.zeros((n_rows,n_cols))
    for r, c, v in zip(rows, cols, vals):
        H_np[r,c]=v
        H_np[c,r]=v
    return H_np

def getEigen(H):
    eigvals, eigvecs = np.linalg.eig(H)
    return eigvals, eigvecs


g = gradient(cp)
H = hessian(cp)

u, U = getEigen(H)

g_p = U.T @ g
g_new = U @ g_p
print(g_p.shape,g_new.shape ,g.shape, H.shape, u.shape, U.shape)
help(cp.hessian)
# Out:
# (101,) (101,) (101,) (101, 101) (101,) (101, 101)
# Help on method hessian in module elastic_knots:
#
# hessian(...) method of elastic_knots.ContactProblem instance
#     hessian(self: elastic_knots.ContactProblem) -> sparse_matrices.TripletMatrix

# %% [markdown]
# for i, R in zip(range(len(path)),path):
#     cp.setDoFs(R)
#     g = gradient(cp)
#     H = hessian(cp)
#     u, U = getEigen(H)
#     with np.printoptions(precision=2):
#         print(f'step: {i}')
#         print(f'Energy: {cp.energy()}')
#         print(f'with Gradient: {np.linalg.norm(g)}')
#         print(f'number of neg Eigenvalues: {len(np.where(u < 0)[0])}')
#         print()
#     view.update()
# cp.setDoFs(path[3])
# view.update()

# %%
#go towards smallest eigenvalue -> collision -> go towards second smallest -> etc
#go towards smallest eigenvalue -> explodes backtrack

# %%
#Newton step method xk+1 = xk −H−1(xk)∇f(xk)
from scipy.sparse.linalg import cg
lam = 0.01
path = [cp.getDoFs()]
n = 1
for i in range (20000):
    R = cp.getDoFs()
    g = gradient(cp)

    H = hessian(cp)
    #kernel dies whlie trying to get the hessian
    u, U = np.linalg.eigh(H)
    #idx = np.where(u < 0)[0]
    idx = np.argmin(u)

    g_p = U.T @ g
    
    #reflect at smallets eigenvalue
    g_p[idx] = -g_p[idx]
    
    #transform back 
    g = U @ g_p

    
    #step = np.linalg.solve(H, g)
    step, _ = cg(H, g)

    #recenter
    pos = step[:75]
    pos  = pos.reshape(-1,3)
    pos  -= pos.mean(axis=0)   
    step[:75] = pos.ravel()
    
    R = R - lam * step
    cp.setDoFs(R)

    path.append(R)
    if i % 100 == 0:
        print(f"it: {i}, current Energy: {cp.energy()}, gradient: {np.linalg.norm(g)}, Postion: {np.linalg.norm(R)}, Num of Neg Eig: {len(np.where(u < 0)[0])}")
        view.update()
# Out:
# it: 0, current Energy: 2.1425517333831396, gradient: 0.1363900078099866, Postion: 192.41084435774866, Num of Neg Eig: 16
# it: 100, current Energy: 1.28620623912177, gradient: 0.1981374105111375, Postion: 206.0066911125749, Num of Neg Eig: 5
# it: 200, current Energy: 0.9113353446218505, gradient: 0.11806067232858618, Postion: 215.8878611163518, Num of Neg Eig: 2
# it: 300, current Energy: 0.7380677297653421, gradient: 0.07435302638998267, Postion: 224.20339679898285, Num of Neg Eig: 2
# it: 400, current Energy: 0.6524500668141693, gradient: 0.0514783516819582, Postion: 232.30736378987638, Num of Neg Eig: 2
# it: 500, current Energy: 0.5983150057877923, gradient: 0.04203695624387556, Postion: 240.69244128141386, Num of Neg Eig: 2
# it: 600, current Energy: 0.5526194917689666, gradient: 0.03971315049649738, Postion: 249.16091712513222, Num of Neg Eig: 2
# it: 700, current Energy: 0.5088184373230856, gradient: 0.038681825304478674, Postion: 257.49043117402135, Num of Neg Eig: 3
# it: 800, current Energy: 0.4670527164261998, gradient: 0.036537173726067275, Postion: 265.59321022952827, Num of Neg Eig: 1
# it: 900, current Energy: 0.4291929104946557, gradient: 0.03322930267377201, Postion: 273.44772960728255, Num of Neg Eig: 3
# it: 1000, current Energy: 0.39670630433942405, gradient: 0.029474622238432755, Postion: 281.0856483674539, Num of Neg Eig: 2
# it: 1100, current Energy: 0.37003813425690135, gradient: 0.026036642740107568, Postion: 288.6088220164421, Num of Neg Eig: 2
# it: 1200, current Energy: 0.3487120796771016, gradient: 0.0234311702751465, Postion: 296.13250818892783, Num of Neg Eig: 3
# it: 1300, current Energy: 0.33172538691234194, gradient: 0.0217937371904806, Postion: 303.69065687681535, Num of Neg Eig: 2
# it: 1400, current Energy: 0.31794483882129326, gradient: 0.02095676018808862, Postion: 311.2566357747451, Num of Neg Eig: 1
# it: 1500, current Energy: 0.30632067336487395, gradient: 0.020720045673102237, Postion: 318.83006315163294, Num of Neg Eig: 1
# it: 1600, current Energy: 0.29593438857955967, gradient: 0.02096687709118505, Postion: 326.4713529958868, Num of Neg Eig: 4
# it: 1700, current Energy: 0.2859869670955927, gradient: 0.021580502225481146, Postion: 334.26724312890315, Num of Neg Eig: 1
# it: 1800, current Energy: 0.27580115924770565, gradient: 0.022397847698013496, Postion: 342.2592969917429, Num of Neg Eig: 2
# it: 1900, current Energy: 0.26484460854827946, gradient: 0.02326670840992073, Postion: 350.4135029327803, Num of Neg Eig: 1
# it: 2000, current Energy: 0.25273902289276884, gradient: 0.024083663649702276, Postion: 358.66810293784727, Num of Neg Eig: 2
# it: 2100, current Energy: 0.23926835109697853, gradient: 0.024755964866666286, Postion: 366.96679078670087, Num of Neg Eig: 1
# it: 2200, current Energy: 0.22441291285736553, gradient: 0.025185622983977193, Postion: 375.2461165782239, Num of Neg Eig: 2
# it: 2300, current Energy: 0.2083910265359422, gradient: 0.025287929901985823, Postion: 383.4155037636582, Num of Neg Eig: 1
# it: 2400, current Energy: 0.19166865193465568, gradient: 0.025019707224340354, Postion: 391.34562917105495, Num of Neg Eig: 2
# it: 2500, current Energy: 0.17490331455226188, gradient: 0.02439395727460189, Postion: 398.87412361376704, Num of Neg Eig: 3
# it: 2600, current Energy: 0.15882672218108068, gradient: 0.02347728741937401, Postion: 405.830836083284, Num of Neg Eig: 1
# it: 2700, current Energy: 0.1441099242609282, gradient: 0.022369259588412318, Postion: 412.0679739441239, Num of Neg Eig: 3
# it: 2800, current Energy: 0.13125648341944038, gradient: 0.021167610859574623, Postion: 417.4820582198212, Num of Neg Eig: 4
# it: 2900, current Energy: 0.1205471898876556, gradient: 0.019938644941089854, Postion: 422.0241518109136, Num of Neg Eig: 1
# it: 3000, current Energy: 0.11203717674800938, gradient: 0.018705603663250393, Postion: 425.6999772717582, Num of Neg Eig: 1
# it: 3100, current Energy: 0.10559160261916199, gradient: 0.017454713507932523, Postion: 428.56296459444974, Num of Neg Eig: 1
# it: 3200, current Energy: 0.1009415994905879, gradient: 0.01615173296305492, Postion: 430.7031280745686, Num of Neg Eig: 0
# it: 3300, current Energy: 0.09774541530119162, gradient: 0.01476188226181508, Postion: 432.2339491632354, Num of Neg Eig: 3
# it: 3400, current Energy: 0.09564511046687049, gradient: 0.013268507607021845, Postion: 433.2792536156103, Num of Neg Eig: 2
# it: 3500, current Energy: 0.09431327934012053, gradient: 0.011690961726970574, Postion: 433.9611520621854, Num of Neg Eig: 1
# it: 3600, current Energy: 0.09348522988688072, gradient: 0.010092369359855113, Postion: 434.3893472543966, Num of Neg Eig: 2
# it: 3700, current Energy: 0.09297148062338215, gradient: 0.008561289686694782, Postion: 434.6528061877958, Num of Neg Eig: 1
# it: 3800, current Energy: 0.09264979688101956, gradient: 0.007168365257597134, Postion: 434.8151369637264, Num of Neg Eig: 2
# it: 3900, current Energy: 0.09244586465790348, gradient: 0.005949154661016377, Postion: 434.916950596631, Num of Neg Eig: 3
# it: 4000, current Energy: 0.09231503847929419, gradient: 0.004910330542912838, Postion: 434.98238939312097, Num of Neg Eig: 2
# it: 4100, current Energy: 0.0922301828082158, gradient: 0.004043038630633087, Postion: 435.0255389462339, Num of Neg Eig: 2
# it: 4200, current Energy: 0.09217454088492619, gradient: 0.003328602947746171, Postion: 435.0547009426527, Num of Neg Eig: 1
# it: 4300, current Energy: 0.092137761896179, gradient: 0.0027387913539971198, Postion: 435.07473226765217, Num of Neg Eig: 3
# it: 4400, current Energy: 0.09211305523778418, gradient: 0.0022651397818977148, Postion: 435.08891813423196, Num of Neg Eig: 1
# it: 4500, current Energy: 0.09209624347029334, gradient: 0.0018816988789337758, Postion: 435.09918002326566, Num of Neg Eig: 1
# it: 4600, current Energy: 0.09208465775042618, gradient: 0.0015647995659106779, Postion: 435.10671237297765, Num of Neg Eig: 1
# it: 4700, current Energy: 0.09207652931465031, gradient: 0.0013175643817286886, Postion: 435.112332755609, Num of Neg Eig: 0
# it: 4800, current Energy: 0.09207077675773565, gradient: 0.0011100153020898286, Postion: 435.1166390793135, Num of Neg Eig: 1
# it: 4900, current Energy: 0.09206664509006696, gradient: 0.0009383223724317571, Postion: 435.1199741185636, Num of Neg Eig: 2
# it: 5000, current Energy: 0.09206363105933052, gradient: 0.0008005003736561645, Postion: 435.12260098982534, Num of Neg Eig: 2
# it: 5100, current Energy: 0.09206140366964768, gradient: 0.0006885401890950915, Postion: 435.12471668795473, Num of Neg Eig: 2
# it: 5200, current Energy: 0.09205974001034753, gradient: 0.0005957498273679201, Postion: 435.12644421596235, Num of Neg Eig: 2
# it: 5300, current Energy: 0.09205848222423697, gradient: 0.00051756970744713, Postion: 435.1278864924395, Num of Neg Eig: 1
# it: 5400, current Energy: 0.0920575213442934, gradient: 0.0004492315392746244, Postion: 435.12910141778656, Num of Neg Eig: 1
# it: 5500, current Energy: 0.09205677920510913, gradient: 0.0003912343646000962, Postion: 435.1301089000737, Num of Neg Eig: 1
# it: 5600, current Energy: 0.09205619177468632, gradient: 0.0003524689183176813, Postion: 435.13098640907515, Num of Neg Eig: 2
# it: 5700, current Energy: 0.09205574767952134, gradient: 0.00030344452575946276, Postion: 435.1317582208353, Num of Neg Eig: 1
# it: 5800, current Energy: 0.09205536811307163, gradient: 0.00028164689818320753, Postion: 435.1324060123115, Num of Neg Eig: 2
# it: 5900, current Energy: 0.09205507548557351, gradient: 0.0002512709601803017, Postion: 435.13297436162077, Num of Neg Eig: 1
# it: 6000, current Energy: 0.0920548404162322, gradient: 0.00022270525982291757, Postion: 435.13348019878856, Num of Neg Eig: 0
# it: 6100, current Energy: 0.09205467015605476, gradient: 0.0001990507687165983, Postion: 435.133956580162, Num of Neg Eig: 4
# it: 6200, current Energy: 0.09205449841790424, gradient: 0.00018780323785424878, Postion: 435.134366332647, Num of Neg Eig: 2
# it: 6300, current Energy: 0.09205436970352669, gradient: 0.0001761153418540958, Postion: 435.1347250236818, Num of Neg Eig: 1
# it: 6400, current Energy: 0.09205426580188918, gradient: 0.00016290264162015575, Postion: 435.13504412486014, Num of Neg Eig: 2
# it: 6500, current Energy: 0.0920541805485134, gradient: 0.00015095144610966142, Postion: 435.13533686054626, Num of Neg Eig: 2
# it: 6600, current Energy: 0.09205411047597319, gradient: 0.00014045764069892523, Postion: 435.1356005017629, Num of Neg Eig: 2
# it: 6700, current Energy: 0.09205405278588327, gradient: 0.000132010534522917, Postion: 435.1358356402685, Num of Neg Eig: 3
# it: 6800, current Energy: 0.09205400512990736, gradient: 0.0001252316855243993, Postion: 435.1360524764951, Num of Neg Eig: 1
# it: 6900, current Energy: 0.09205396584158854, gradient: 0.00011984812563865773, Postion: 435.13625059486, Num of Neg Eig: 2
# it: 7000, current Energy: 0.09205393359249432, gradient: 0.00011603584880491715, Postion: 435.1364324942074, Num of Neg Eig: 2
# it: 7100, current Energy: 0.09205391245587173, gradient: 0.00012267473757875764, Postion: 435.13660555552593, Num of Neg Eig: 1
# it: 7200, current Energy: 0.09205389972372903, gradient: 9.867204075655347e-05, Postion: 435.13672526234745, Num of Neg Eig: 1
# it: 7300, current Energy: 0.0920538635954378, gradient: 8.399422348744274e-05, Postion: 435.136841350069, Num of Neg Eig: 0
# it: 7400, current Energy: 0.09205384812727846, gradient: 8.499806745070414e-05, Postion: 435.13696523118034, Num of Neg Eig: 1
# it: 7500, current Energy: 0.09205383565953339, gradient: 8.731452146298146e-05, Postion: 435.13707978600814, Num of Neg Eig: 2
# it: 7600, current Energy: 0.09205382548078725, gradient: 9.139875337345484e-05, Postion: 435.13718658819965, Num of Neg Eig: 3
# it: 7700, current Energy: 0.09205381735832396, gradient: 9.686697681859762e-05, Postion: 435.1372892737782, Num of Neg Eig: 2
# it: 7800, current Energy: 0.09205382095223402, gradient: 8.128439583746809e-05, Postion: 435.1373494112073, Num of Neg Eig: 2
# it: 7900, current Energy: 0.09205380199511184, gradient: 7.250468721597814e-05, Postion: 435.1374205449908, Num of Neg Eig: 1
# it: 8000, current Energy: 0.09205379748372468, gradient: 8.012740369735505e-05, Postion: 435.13749848816457, Num of Neg Eig: 1
# it: 8100, current Energy: 0.09205379405717214, gradient: 8.93879771121244e-05, Postion: 435.1375742583423, Num of Neg Eig: 1
# it: 8200, current Energy: 0.09205382356666483, gradient: 0.00011385434074434439, Postion: 435.13762897404547, Num of Neg Eig: 2
# it: 8300, current Energy: 0.09205378614601029, gradient: 6.888037356615235e-05, Postion: 435.13765969096454, Num of Neg Eig: 1
# it: 8400, current Energy: 0.09205378448936885, gradient: 7.97511267768236e-05, Postion: 435.13772299637355, Num of Neg Eig: 2
# it: 8500, current Energy: 0.092053783818352, gradient: 9.422499090837208e-05, Postion: 435.1377827526101, Num of Neg Eig: 1
# it: 8600, current Energy: 0.09205377974803991, gradient: 6.362728100028412e-05, Postion: 435.13778581162586, Num of Neg Eig: 1
# it: 8700, current Energy: 0.0920537791688191, gradient: 7.637862645485275e-05, Postion: 435.13783831091695, Num of Neg Eig: 0
# it: 8800, current Energy: 0.0920537793663949, gradient: 9.277321179161452e-05, Postion: 435.13788939097384, Num of Neg Eig: 1
# it: 8900, current Energy: 0.09205377618834065, gradient: 6.305510959874737e-05, Postion: 435.13788785450924, Num of Neg Eig: 3
# it: 9000, current Energy: 0.09205377635482215, gradient: 7.788683943674655e-05, Postion: 435.1379334835661, Num of Neg Eig: 3
# it: 9100, current Energy: 0.09205378344200746, gradient: 0.00012534125387644426, Postion: 435.13798677930487, Num of Neg Eig: 1
# it: 9200, current Energy: 0.09205377438583046, gradient: 6.697621580258432e-05, Postion: 435.1379661559623, Num of Neg Eig: 1
# it: 9300, current Energy: 0.09205377520305126, gradient: 8.488225315702713e-05, Postion: 435.13800805499, Num of Neg Eig: 0
# it: 9400, current Energy: 0.0920537732330716, gradient: 5.889138669134703e-05, Postion: 435.1379997335998, Num of Neg Eig: 0
# it: 9500, current Energy: 0.09205377381129103, gradient: 7.568994966634105e-05, Postion: 435.13803222660107, Num of Neg Eig: 2
# it: 9600, current Energy: 0.09205378844692366, gradient: 0.00014878436446705772, Postion: 435.13808209123084, Num of Neg Eig: 1
# it: 9700, current Energy: 0.09205377287775765, gradient: 6.9125667487538e-05, Postion: 435.1380536071786, Num of Neg Eig: 2
# it: 9800, current Energy: 0.09205377444319891, gradient: 9.227207971514739e-05, Postion: 435.1380970830093, Num of Neg Eig: 3
# it: 9900, current Energy: 0.09205377225173644, gradient: 6.465629908975716e-05, Postion: 435.1380786994909, Num of Neg Eig: 2
# it: 10000, current Energy: 0.09205377370191643, gradient: 8.684035151519356e-05, Postion: 435.1381133916911, Num of Neg Eig: 2
# it: 10100, current Energy: 0.09205377181326396, gradient: 6.118795753137576e-05, Postion: 435.1380928335151, Num of Neg Eig: 1
# it: 10200, current Energy: 0.09205377329058832, gradient: 8.416145722084529e-05, Postion: 435.13812690500276, Num of Neg Eig: 2
# it: 10300, current Energy: 0.09205377163169351, gradient: 6.079170146108882e-05, Postion: 435.13810962771765, Num of Neg Eig: 3
# it: 10400, current Energy: 0.09205377334202335, gradient: 8.647961705490053e-05, Postion: 435.1381424664664, Num of Neg Eig: 2
# it: 10500, current Energy: 0.09205377180775862, gradient: 6.557936306981064e-05, Postion: 435.1381272591883, Num of Neg Eig: 2
# it: 10600, current Energy: 0.09205377509843495, gradient: 0.00010484409237892806, Postion: 435.13817808265736, Num of Neg Eig: 2
# it: 10700, current Energy: 0.09205377218173015, gradient: 7.253537274360682e-05, Postion: 435.1381474131738, Num of Neg Eig: 0
# it: 10800, current Energy: 0.092053771038288, gradient: 5.376751060682658e-05, Postion: 435.13813499106305, Num of Neg Eig: 2
# it: 10900, current Energy: 0.09205377085279265, gradient: 5.043055452754498e-05, Postion: 435.1381354518939, Num of Neg Eig: 2
# it: 11000, current Energy: 0.09205378597596735, gradient: 6.425288539418414e-05, Postion: 435.13813254867745, Num of Neg Eig: 2
# it: 11100, current Energy: 0.09205381955789384, gradient: 0.000255636011699037, Postion: 435.138251970245, Num of Neg Eig: 2
# it: 11200, current Energy: 0.0920538943659792, gradient: 0.0002446383726886028, Postion: 435.1382481087357, Num of Neg Eig: 4
# it: 11300, current Energy: 0.09205377054285066, gradient: 4.508297671778288e-05, Postion: 435.13814379527133, Num of Neg Eig: 2
# it: 11400, current Energy: 0.09205377094577127, gradient: 5.376830148099575e-05, Postion: 435.1381561978149, Num of Neg Eig: 1
# it: 11500, current Energy: 0.0920537733425473, gradient: 8.968934480719381e-05, Postion: 435.1381979083072, Num of Neg Eig: 3
# it: 11600, current Energy: 0.09205377333244841, gradient: 8.956808019098208e-05, Postion: 435.13820192309737, Num of Neg Eig: 1
# it: 11700, current Energy: 0.09205377333530625, gradient: 8.96285663981349e-05, Postion: 435.138201690023, Num of Neg Eig: 3
# it: 11800, current Energy: 0.09205377557399243, gradient: 0.00011331463491131922, Postion: 435.1382212913759, Num of Neg Eig: 1
# it: 11900, current Energy: 0.09205377547142655, gradient: 0.0001122884302460414, Postion: 435.1382278764931, Num of Neg Eig: 0
# it: 12000, current Energy: 0.0920537731174828, gradient: 8.717573604391034e-05, Postion: 435.13820304798503, Num of Neg Eig: 2
# it: 12100, current Energy: 0.09205377446961405, gradient: 0.00010247438586569887, Postion: 435.13821885483793, Num of Neg Eig: 1
# it: 12200, current Energy: 0.09205377378872674, gradient: 9.511571494308484e-05, Postion: 435.13821337899697, Num of Neg Eig: 2
# it: 12300, current Energy: 0.09205377216167984, gradient: 7.4622628178804e-05, Postion: 435.1381938623527, Num of Neg Eig: 2
# it: 12400, current Energy: 0.0920537714267164, gradient: 6.332871283738804e-05, Postion: 435.13818130261467, Num of Neg Eig: 1
# it: 12500, current Energy: 0.09205377091552976, gradient: 5.4093302331837806e-05, Postion: 435.13817224553145, Num of Neg Eig: 3
# it: 12600, current Energy: 0.09205377466153693, gradient: 0.00010446648409588157, Postion: 435.13822664825506, Num of Neg Eig: 3
# it: 12700, current Energy: 0.09205377539479227, gradient: 0.00011188670956814685, Postion: 435.13824223833285, Num of Neg Eig: 0
# it: 12800, current Energy: 0.09205377032406037, gradient: 4.09553975332661e-05, Postion: 435.13816303561623, Num of Neg Eig: 3
# it: 12900, current Energy: 0.09205377151447798, gradient: 6.503795850672464e-05, Postion: 435.13818538862324, Num of Neg Eig: 1
# it: 13000, current Energy: 0.09205377155906004, gradient: 6.570897061252535e-05, Postion: 435.1381876894806, Num of Neg Eig: 3
# it: 13100, current Energy: 0.09205377206523904, gradient: 7.350448316114394e-05, Postion: 435.13819683001145, Num of Neg Eig: 1
# it: 13200, current Energy: 0.09205377168492238, gradient: 6.766963568556357e-05, Postion: 435.13818924189627, Num of Neg Eig: 2
# it: 13300, current Energy: 0.0920537736844458, gradient: 9.402454503113979e-05, Postion: 435.13822431542417, Num of Neg Eig: 3
# it: 13400, current Energy: 0.09205377509059427, gradient: 0.00010887518225137681, Postion: 435.13823940246465, Num of Neg Eig: 3
# it: 13500, current Energy: 0.09205377258901846, gradient: 8.079977694838009e-05, Postion: 435.1382093724718, Num of Neg Eig: 0
# it: 13600, current Energy: 0.0920537751166591, gradient: 0.00010935356798975126, Postion: 435.13824931018297, Num of Neg Eig: 2
# it: 13700, current Energy: 0.0920537738569542, gradient: 9.585832481788604e-05, Postion: 435.1382294494699, Num of Neg Eig: 0
# it: 13800, current Energy: 0.09205377125575495, gradient: 3.598745085940206e-05, Postion: 435.1381651542605, Num of Neg Eig: 2
# it: 13900, current Energy: 0.09205377112104238, gradient: 5.8186600778790745e-05, Postion: 435.1381923701213, Num of Neg Eig: 2
# it: 14000, current Energy: 0.09205377203073974, gradient: 5.135286698629654e-05, Postion: 435.1381831871169, Num of Neg Eig: 2
# it: 14100, current Energy: 0.09205378114006642, gradient: 0.0001749609345362451, Postion: 435.1382676109535, Num of Neg Eig: 2
# it: 14200, current Energy: 0.09205377340443881, gradient: 9.074650495161046e-05, Postion: 435.13822520242985, Num of Neg Eig: 4
# it: 14300, current Energy: 0.09205377005415206, gradient: 3.321623378731171e-05, Postion: 435.1381626395387, Num of Neg Eig: 2
# it: 14400, current Energy: 0.09205377328282319, gradient: 8.968512272540198e-05, Postion: 435.1382298179983, Num of Neg Eig: 2
# it: 14500, current Energy: 0.09205377528544265, gradient: 0.00011100482197879861, Postion: 435.1382532160299, Num of Neg Eig: 1
# it: 14600, current Energy: 0.0920537758140818, gradient: 0.0001156619601730896, Postion: 435.1382633781423, Num of Neg Eig: 3
# it: 14700, current Energy: 0.0920537758848321, gradient: 0.00011644455999057118, Postion: 435.13826457793465, Num of Neg Eig: 3
# it: 14800, current Energy: 0.09205377487529437, gradient: 0.000106774476469314, Postion: 435.13824748409183, Num of Neg Eig: 1
# it: 14900, current Energy: 0.09205377415451121, gradient: 9.923849994087406e-05, Postion: 435.1382371718906, Num of Neg Eig: 1
# it: 15000, current Energy: 0.09205377524243165, gradient: 0.0001104497133504392, Postion: 435.13825130186774, Num of Neg Eig: 2
# it: 15100, current Energy: 0.09205377396391898, gradient: 9.713100392343783e-05, Postion: 435.1382373706577, Num of Neg Eig: 2
# it: 15200, current Energy: 0.09205377331951224, gradient: 8.982260346858083e-05, Postion: 435.1382271689315, Num of Neg Eig: 3
# it: 15300, current Energy: 0.09205377213429942, gradient: 7.44829041713986e-05, Postion: 435.13821039776633, Num of Neg Eig: 1
# it: 15400, current Energy: 0.09205377128166015, gradient: 6.102834269356908e-05, Postion: 435.13819468885305, Num of Neg Eig: 1
# it: 15500, current Energy: 0.09205377074473411, gradient: 5.079083629726499e-05, Postion: 435.1381839663843, Num of Neg Eig: 2
# it: 15600, current Energy: 0.0920537713490747, gradient: 6.223970966243128e-05, Postion: 435.13819699707545, Num of Neg Eig: 2
# it: 15700, current Energy: 0.09205377692531805, gradient: 5.44019888125344e-05, Postion: 435.1381765119961, Num of Neg Eig: 1
# it: 15800, current Energy: 0.09205377047822948, gradient: 4.4802364061155363e-05, Postion: 435.1381768721992, Num of Neg Eig: 1
# it: 15900, current Energy: 0.09205379216312538, gradient: 0.00020951323015888854, Postion: 435.138493681923, Num of Neg Eig: 2
# it: 16000, current Energy: 0.09205377233154893, gradient: 7.604491123981834e-05, Postion: 435.13824434199046, Num of Neg Eig: 3
# it: 16100, current Energy: 0.09205377163470684, gradient: 6.64043985058191e-05, Postion: 435.13822892526844, Num of Neg Eig: 1
# it: 16200, current Energy: 0.09205377121708375, gradient: 5.936970777546744e-05, Postion: 435.13821898861625, Num of Neg Eig: 2
# it: 16300, current Energy: 0.09205377211299302, gradient: 7.397015195672193e-05, Postion: 435.1382308475975, Num of Neg Eig: 2
# it: 16400, current Energy: 0.09205377098805856, gradient: 5.550000043073626e-05, Postion: 435.13820610007764, Num of Neg Eig: 2
# it: 16500, current Energy: 0.0920538476406243, gradient: 0.00013225191595453702, Postion: 435.13823563624175, Num of Neg Eig: 2
# it: 16600, current Energy: 0.09205377468232374, gradient: 0.00010480106903486925, Postion: 435.13825223236677, Num of Neg Eig: 1
# it: 16700, current Energy: 0.09205377246289656, gradient: 7.899753082269692e-05, Postion: 435.1382221441351, Num of Neg Eig: 1
# it: 16800, current Energy: 0.09205377120028292, gradient: 5.9549700580427975e-05, Postion: 435.1382028131877, Num of Neg Eig: 1
# it: 16900, current Energy: 0.09205385193842486, gradient: 0.00012516123973264372, Postion: 435.1382315589617, Num of Neg Eig: 3
# it: 17000, current Energy: 0.09205377395769125, gradient: 9.704531585562267e-05, Postion: 435.1382438587809, Num of Neg Eig: 2
# it: 17100, current Energy: 0.09205377339820782, gradient: 9.06931610500233e-05, Postion: 435.1382380754673, Num of Neg Eig: 2
# it: 17200, current Energy: 0.09205377276561463, gradient: 8.296147970920956e-05, Postion: 435.13822789055916, Num of Neg Eig: 1
# it: 17300, current Energy: 0.09205377347838291, gradient: 9.171387027991288e-05, Postion: 435.13823492638096, Num of Neg Eig: 1
# it: 17400, current Energy: 0.09205377282540507, gradient: 8.371275706192234e-05, Postion: 435.1382237712889, Num of Neg Eig: 2
# it: 17500, current Energy: 0.09205377230408268, gradient: 7.669100748196432e-05, Postion: 435.1382168757326, Num of Neg Eig: 2
# it: 17600, current Energy: 0.09205378469914226, gradient: 3.52350900928217e-05, Postion: 435.13816374975517, Num of Neg Eig: 1
# it: 17700, current Energy: 0.09205377175954738, gradient: 6.885059381702788e-05, Postion: 435.13821461019745, Num of Neg Eig: 2
# it: 17800, current Energy: 0.09205377125971331, gradient: 6.058399591676146e-05, Postion: 435.13820428230775, Num of Neg Eig: 1
# it: 17900, current Energy: 0.09205377459420323, gradient: 0.00010407329103524387, Postion: 435.1382427028916, Num of Neg Eig: 2
# it: 18000, current Energy: 0.09205377262130157, gradient: 8.122464598682955e-05, Postion: 435.13822275175755, Num of Neg Eig: 3
# it: 18100, current Energy: 0.09205377345766046, gradient: 9.153733402821469e-05, Postion: 435.1382369433395, Num of Neg Eig: 1
# it: 18200, current Energy: 0.09205377247161182, gradient: 7.913620047423123e-05, Postion: 435.13822250476824, Num of Neg Eig: 2
# it: 18300, current Energy: 0.09205377159639104, gradient: 6.623624716669413e-05, Postion: 435.13820590711344, Num of Neg Eig: 1
# it: 18400, current Energy: 0.0920537718325116, gradient: 6.995113848530281e-05, Postion: 435.1382066536226, Num of Neg Eig: 2
# it: 18500, current Energy: 0.0920537708318068, gradient: 5.255257976745687e-05, Postion: 435.1381882679717, Num of Neg Eig: 1
# it: 18600, current Energy: 0.0920537706739165, gradient: 4.896949993764711e-05, Postion: 435.1381857669769, Num of Neg Eig: 1
# it: 18700, current Energy: 0.09205381884113784, gradient: 0.00022574532744966833, Postion: 435.1382764671921, Num of Neg Eig: 2
# it: 18800, current Energy: 0.09205377325037448, gradient: 8.895995803137389e-05, Postion: 435.13823084995204, Num of Neg Eig: 0
# it: 18900, current Energy: 0.09205377212763234, gradient: 7.430497179165649e-05, Postion: 435.13821345682396, Num of Neg Eig: 0
# it: 19000, current Energy: 0.09205377182561648, gradient: 6.981715752271677e-05, Postion: 435.13820817731, Num of Neg Eig: 3
# it: 19100, current Energy: 0.0920537709824385, gradient: 5.361418571175199e-05, Postion: 435.13818909520637, Num of Neg Eig: 0
# it: 19200, current Energy: 0.09205381210327822, gradient: 0.00026890530956090496, Postion: 435.1382966788081, Num of Neg Eig: 4
# it: 19300, current Energy: 0.09205377352002819, gradient: 9.197527227037893e-05, Postion: 435.1382311322922, Num of Neg Eig: 2
# it: 19400, current Energy: 0.09205377222883954, gradient: 7.572124119908008e-05, Postion: 435.13821527990564, Num of Neg Eig: 1
# it: 19500, current Energy: 0.0920537749086911, gradient: 0.00010715001906505901, Postion: 435.13824492821453, Num of Neg Eig: 3
# it: 19600, current Energy: 0.092053772473972, gradient: 7.9043769719248e-05, Postion: 435.13821658284655, Num of Neg Eig: 2
# it: 19700, current Energy: 0.09205377119324781, gradient: 5.934102515849029e-05, Postion: 435.1381933262584, Num of Neg Eig: 1
# it: 19800, current Energy: 0.09205377104893155, gradient: 5.665577426973244e-05, Postion: 435.13819149718233, Num of Neg Eig: 2
# it: 19900, current Energy: 0.09205378230073043, gradient: 0.0001855652660019337, Postion: 435.13825267545224, Num of Neg Eig: 2

# %% [markdown]
# step = 0.01
# path = [cp.getDoFs()]
# n = 1
#
# for i in range (1000000):
#     R = cp.getDoFs()
#     g = gradient(cp)
#
#     H = hessian(cp)
#
#     u, U = np.linalg.eigh(H)
#     #idx = np.argsort(u)[:n]
#     #idx = np.argmin(u)
#     idx = np.where(u < 0)[0]
#     #find principal gradients
#     g_p = U.T @ g
#
#     #reflect at smallets eigenvalue
#     g_p[idx] = -g_p[idx]
#
#     #transform back
#     g = U @ g_p
#
#
#
#     R = R - step * g
#
#     cp.setDoFs(R)
#     path.append(R)
#     if i % 100 == 0:
#         print(f"it: {i}, current Energy: {cp.energy()}, gradient: {np.linalg.norm(g)}, Postion: {np.linalg.norm(R)}, Type: {len(idx)}")
#         view.update()
