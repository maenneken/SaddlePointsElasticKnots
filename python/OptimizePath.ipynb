# %%
import sys; sys.path.append('../3rdparty/ElasticRods/python')
import elastic_rods, elastic_knots
import numpy as np, matplotlib.pyplot as plt, time, io, os

from helpers import *
from parametric_curves import *
import py_newton_optimizer

from linkage_vis import LinkageViewer as Viewer, CenterlineViewer
from tri_mesh_viewer import PointCloudViewer, PointCloudMesh

# %load_ext autoreload
# %autoreload 2

import parallelism
parallelism.set_max_num_tbb_threads(1)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
file = "../data/L400-r0.2-UpTo9Crossings/4_1/0033.obj"
rod_radius = 0.2
material = elastic_rods.RodMaterial('ellipse', 2000, 0.3, [rod_radius, rod_radius])
centerline = read_nodes_from_file(file)[::4]  # supported formats: obj, txt
pr = define_periodic_rod(centerline, material)
rod_list = elastic_knots.PeriodicRodList([pr])

problemOptions = elastic_knots.ContactProblemOptions()
problemOptions.hasCollisions = True
problemOptions.contactStiffness = 10000
problemOptions.dHat = 2*rod_radius

contactProblem = elastic_knots.ContactProblem(rod_list,problemOptions)

print( f"Gradient length: {len(rod_list.gradient())},DoFs length: {len(rod_list.getDoFs())}")
# Out:
# Gradient length: 401,DoFs length: 401

# %%
pathFile = 'optimizedoptimizedshortendASaddleBpath.npz'
loaded = np.load('Paths/'+pathFile)
path = [loaded[key] for key in loaded.files]
path = path
#pathFile = 'quater'+pathFile
rod_list.setDoFs(path[0])
print(len(path))
# Out:
# 18

# %%
view = Viewer(rod_list, width=1024, height=800)
view.show()
# Out:
# Renderer(camera=PerspectiveCamera(aspect=1.28, children=(PointLight(color='#999999', position=(0.0, 0.0, 5.0),…

# %%
def show_path(rod, path, view, wait=0.05):
    for DoFs in path:
        rod.setDoFs(DoFs)
        time.sleep(wait)
        view.update()
show_path(contactProblem,path,view,wait = 0)

def getPathEnergy(path, rod, view):
    path_energy=[]
    for DoFs in path:
        rod.setDoFs(DoFs)
        path_energy.append(rod.energy())
        view.update()
    return path_energy
energy = getPathEnergy(path, contactProblem,view)

def getPathGradient(path, rod):
    path_gradient=[]
    for DoFs in path:
        rod.setDoFs(DoFs)
        path_gradient.append(rod.gradient())
    return path_gradient
path_gradient = getPathGradient(path, contactProblem)

def safe_normalize(v, eps=1e-12):
    norm = np.linalg.norm(v)
    if norm < eps or np.isnan(norm):
        return np.zeros_like(v)
    return v / norm

def getTangent(R_pre, R_next):
    t = R_next - R_pre
    t = safe_normalize(t)
    return np.array(t)

print(np.array(getTangent(path[0],path[2])).shape)

# F_spring = k * (||R_{i+1} - R_i|| - ||R_i - R_{i-1}||) * tangent_i
def getSpringForce(R_pre,R, R_next):
    k = 2
    tangent = getTangent(R_pre, R_next)
    F = k*(np.linalg.norm(R_next-R)-np.linalg.norm(R-R_pre))*tangent
    return np.array(F)
print(np.array(getSpringForce(*path[:3])).shape)

#F_perp =-d_R_{i} + d_R_{i}°tangent_i*tanget_i
def getPerpForce(d_R,R_pre, R_next):
    tangent = getTangent(R_pre, R_next)
    F= (-d_R + (np.dot(d_R,tangent) * tangent))
    return np.array(F)
print(np.array(getPerpForce(path_gradient[0], path[0],path[2])).shape)

def getNEBForce(d_R,R_pre, R, R_next):
    return getPerpForce(d_R,R_pre, R_next) + getSpringForce(R_pre,R, R_next)

print(np.array(getNEBForce(path_gradient[0],*path[:3])).shape)
# Out:
# (401,)
# (401,)
# (401,)
# (401,)

# %%
path_energy = getPathEnergy(path,contactProblem,view)
plt.plot(range(len(path_energy)),path_energy)

plt.show()
print(f"Path energy: {sum(path_energy)}")
# Out:
# Path energy: 46.59384486567372

# %%
def optimize_rod_path_dofs(R, rod, step_size=0.00002, iterations=10000, gradTol = 3e-3):
    import time
    import numpy as np

    # Initialize per-knot step sizes
    step_size = np.full(len(R), step_size)
    prevE = np.full(len(R), np.inf)
    start_time = time.time()
    for it in range(iterations + 1):
        totalE = 0.0
        totalGradNorm = 0
        for i in range(1, len(R) - 1):  # skip fixed endpoints
            rod.setDoFs(R[i])
            d_R = rod.gradient()
            F = getNEBForce(d_R, R[i - 1], R[i], R[i + 1])
            E = rod.energy()
            totalE += E
            totalGradNorm += np.linalg.norm(d_R)
            # Compare force magnitudes to adapt step size per knot
            if E < prevE[i]: 
                step_size[i] *= 1.05  # Gradually increase
            else:
                step_size[i] *= 0.5   # Back off if divergence
    
            step_size[i] = np.clip(step_size[i], 1e-5, 1e-2)

            prevE[i] = E
            
            R[i] += step_size[i] * F  # Gradient ascent — be sure F is negative grad if you want descent
        
        
        if (totalGradNorm / (len(R)-2)) < gradTol:
            print(f"Converged at iteration {it}")
            break
  

        if it % 100 == 0:
            print(f"{it} totalEnergy = {totalE:.6f}, after {(time.time() - start_time):.2f}s")
            print(f"  step_size (min/max): {step_size.min():.2e} / {step_size.max():.2e} mean: {np.mean(step_size)}")
            print(f"  total gradient normalised: {totalGradNorm}")

    return R  
new_path = optimize_rod_path_dofs(path, contactProblem, iterations=1000000)
# Out:
# 0 totalEnergy = 44.973579, after 0.01s
#   step_size (min/max): 2.00e-05 / 2.10e-05 mean: 2.088888888888889e-05
#   total gradient normalised: 21.7111579299948
# 100 totalEnergy = 43.608583, after 0.54s
#   step_size (min/max): 2.00e-05 / 2.76e-03 mean: 0.002456912368686564
#   total gradient normalised: 13.667366310296046
# 200 totalEnergy = 39.482008, after 1.04s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.006942328736979167
#   total gradient normalised: 11.916804676834468
# 300 totalEnergy = 37.309192, after 1.55s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.008204600415335807
#   total gradient normalised: 5.850522209774414
# 400 totalEnergy = 35.635081, after 2.06s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.006356575820529516
#   total gradient normalised: 8.530841727028038
# 500 totalEnergy = 34.264877, after 2.56s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.00867022631296011
#   total gradient normalised: 4.8882889070924715
# 600 totalEnergy = 33.089474, after 3.07s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.006187859954721682
#   total gradient normalised: 5.136708707777039
# 700 totalEnergy = 32.057274, after 3.59s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.008834404535006148
#   total gradient normalised: 4.535942598037583
# 800 totalEnergy = 31.150980, after 4.11s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.006839008073195877
#   total gradient normalised: 4.290323709176556
# 900 totalEnergy = 30.318586, after 4.62s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.008859346983978677
#   total gradient normalised: 5.7247997140513975
# 1000 totalEnergy = 29.582146, after 5.15s
#   step_size (min/max): 2.00e-05 / 9.90e-03 mean: 0.007660921278866086
#   total gradient normalised: 4.228053804992497
# 1100 totalEnergy = 28.891667, after 5.68s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.006766805555555557
#   total gradient normalised: 6.916944212757008
# 1200 totalEnergy = 28.269448, after 6.21s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.008474356067096294
#   total gradient normalised: 3.3699059297210723
# 1300 totalEnergy = 27.686478, after 6.74s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.005734840976562502
#   total gradient normalised: 3.367648557228754
# 1400 totalEnergy = 27.152388, after 7.27s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.008570111354660402
#   total gradient normalised: 3.1411131277460953
# 1500 totalEnergy = 26.657267, after 7.80s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.006656310684956628
#   total gradient normalised: 3.0663342356680436
# 1600 totalEnergy = 26.189385, after 8.34s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.008651097768513092
#   total gradient normalised: 3.4169339369783707
# 1700 totalEnergy = 25.762246, after 8.88s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.0077484226082045375
#   total gradient normalised: 3.001094585659082
# 1800 totalEnergy = 25.352700, after 9.41s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.007436218623119017
#   total gradient normalised: 4.56787063219597
# 1900 totalEnergy = 24.977589, after 9.94s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.008279291909125715
#   total gradient normalised: 3.1333093299777848
# 2000 totalEnergy = 24.618733, after 10.47s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.006314194206439916
#   total gradient normalised: 3.656172574364945
# 2100 totalEnergy = 24.284733, after 11.00s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.008553334852318158
#   total gradient normalised: 2.564646613453819
# 2200 totalEnergy = 23.971202, after 11.52s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.006609399264839555
#   total gradient normalised: 3.1957209467115515
# 2300 totalEnergy = 23.672518, after 12.04s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.008389843847066501
#   total gradient normalised: 3.3337768439137054
# 2400 totalEnergy = 23.394333, after 12.55s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.007327913979301898
#   total gradient normalised: 2.3094057678870343
# 2500 totalEnergy = 23.128334, after 13.07s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.007220106514756945
#   total gradient normalised: 3.532469764895893
# 2600 totalEnergy = 22.879726, after 13.58s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.008052931521364909
#   total gradient normalised: 2.1435649804642707
# 2700 totalEnergy = 22.641781, after 14.10s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.006604316293050159
#   total gradient normalised: 2.7761132885558255
# 2800 totalEnergy = 22.418481, after 14.62s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.0084259392382702
#   total gradient normalised: 2.242848073810763
# 2900 totalEnergy = 22.206063, after 15.14s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.007113690939936306
#   total gradient normalised: 2.476792017289344
# 3000 totalEnergy = 22.003800, after 15.66s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.008161071200157362
#   total gradient normalised: 2.187231624143194
# 3100 totalEnergy = 21.813066, after 16.18s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.007352745958209708
#   total gradient normalised: 1.9468282882283108
# 3200 totalEnergy = 21.630299, after 16.70s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.007910187447056414
#   total gradient normalised: 2.4141861842822707
# 3300 totalEnergy = 21.457991, after 17.22s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.008033037365577537
#   total gradient normalised: 2.13783834702389
# 3400 totalEnergy = 21.292380, after 17.74s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.007060591524084124
#   total gradient normalised: 2.272017388067898
# 3500 totalEnergy = 21.135724, after 18.26s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.007995287762040396
#   total gradient normalised: 2.068848943809758
# 3600 totalEnergy = 20.985665, after 18.79s
#   step_size (min/max): 2.00e-05 / 1.00e-02 mean: 0.007374534511069891
#   total gradient normalised: 1.9507016337201548
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 43
#      40             print(f"  total gradient normalised: {totalGradNorm}")
#      42     return R
# ---> 43 new_path = optimize_rod_path_dofs(path, contactProblem, iterations=1000000)
#
# Cell In[32], line 13, in optimize_rod_path_dofs(R, rod, step_size, iterations, gradTol)
#      11 totalGradNorm = 0
#      12 for i in range(1, len(R) - 1):  # skip fixed endpoints
# ---> 13     rod.setDoFs(R[i])
#      14     d_R = rod.gradient()
#      15     F = getNEBForce(d_R, R[i - 1], R[i], R[i + 1])
#
# KeyboardInterrupt:

# %%
new_path_energy = getPathEnergy(new_path,contactProblem,view)
plt.plot(range(len(path_energy)),path_energy)
plt.plot(range(len(new_path_energy)),new_path_energy)
plt.show()
print(f"Path old energy: {sum(path_energy)}, Path new energy: {sum(new_path_energy)}")
print(f"difference:  {sum(path_energy)- sum(new_path_energy)}")

# %%
time.sleep(3)
#show_path(rod_list,path,view)
show_path(rod_list,new_path,view,wait=0.5)

# %%
np.savez('Paths/optimized'+pathFile, *new_path)
